# %%
import pandas as pd

# %%
pip install pyCanDI
# Out:
# Requirement already satisfied: pyCanDI in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (0.2.5)
# Requirement already satisfied: pandas in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pyCanDI) (2.3.1)
# Requirement already satisfied: configparser in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pyCanDI) (7.2.0)
# Requirement already satisfied: requests in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pyCanDI) (2.32.4)
# Requirement already satisfied: tqdm in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pyCanDI) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pandas->pyCanDI) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pandas->pyCanDI) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pandas->pyCanDI) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from pandas->pyCanDI) (2025.2)
# Requirement already satisfied: six>=1.5 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pyCanDI) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from requests->pyCanDI) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from requests->pyCanDI) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from requests->pyCanDI) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages (from requests->pyCanDI) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import CanDI.candi as can

# %%
Model = pd.read_csv('../CanDI/setup/data/depmap/24Q2/Model.csv.gz').head()

# %%
# can.data.cell_lines.loc[prism_data.obs.index.to_list(),:]

# %%
# Model.set_index('ModelID').loc[prism_data.obs.index.to_list(),:]

# %% [markdown]
# ---

# %% [markdown]
# # PRISM Repurposing dataset

# %% [markdown]
#     # ----------------------------- #
#     # ---- DATASET DESCRIPTION ---- #
#     # ----------------------------- #
#
#     This data release contains two most recent PRISM Repurposing screens: Repurposing-1M and Repurposing-300. All Repurposing-1M [REP1M] and Repurposing-300 [REP300] compounds (1522 = 1280 REP1M + 242 REP300) were screened in the PRISM assay at a dose of 2.5 μM with a 5-day treatment against 906 cancer cell lines (859 of them passed quality checks -QC- for all tested compound with two high quality replicates). Two PRISM cell line collections were used in the assay: PR500A, which includes only adherent cell lines, and PR500B, which has adherent and suspension cell lines. Together, these PRISM cell line collections form the PR1000 cell line collection. All compounds were run in triplicate, and each plate contained positive (Bortezomib, 20μM) and negative (DMSO) controls. The screen can be considered an extension of the PRISM Repurposing Primary Screen, with PR500A mainly covering the existing cell line panel, while PR500B extends the cell line collection with new subtypes and lineages. For the assay details, please refer to Corsello et al., 2020 (doi.org/10.1038/s43018-019-0018-6) and https://www.theprismlab.org.
#
#
#
#     # ------------------------------ #
#     # ---- DATA PROCESSING & QC ---- #
#     # ------------------------------ #
#
#     The screen is executed using 384-well assay-ready compound plates where each plate has 32 negative (DMSO) and positive (20uM Bortezomib) control wells beside ~300 test compounds. Each compound plate is screened in three biological replicates with a randomized plate map for each replicate. The output of the Luminex detection step at the assay endpoint (5 days) is the fluorescence intensity levels for each bead-replicate pair. The code and more detailed description of the data processing and QC steps are available at https://github.com/broadinstitute/repurposing and https://github.com/broadinstitute/prism_data_processing. Below, we give a brief description of those steps by pointing out which files in the release package have the output of each step.
#
#
#         1. The median fluorescence intensity (MFI) of each bead-replicate pair is calculated and log2-transformed. (Repurposing_Public_24Q2_LMFI_matrix.csv)
#
#         2. LMFI values are normalized to inert controls in the same condition on the same plate. (LMFI.normalized column in the Repurposing_Public_24Q2_LMFI_NORMALIZED.csv)
#
#         3. For each detection plate x cell line pair, a control separation filter is applied for quality control purposes. In particular, for each pair, the Bayes error of a classifier to separate negative and positive control wells is computed along with the dynamic range of the signal (defined as the difference between median LMFI.normalized of DMSO and  Bortezomib wells). Any pair with an error rate more than 5% or dynamic range less than 2 are flagged as QC failures. The flagged cell line x detection plate pairs are filtered out as well as any cell lines x compound plate with fewer than two passing replicates from the downstream analysis (see Repurposing_Public_24Q2_QC_table.csv).
#
#         4. Log2-fold-change is calculated for each condition relative to negative-control wells from the same cell line on the same detection plate, positive-control and negative-control treatments are removed. (LFC column of Repurposing_Public_24Q2_LFC.csv)
#
#         5. ComBat batch correction method (DOI: 10.1093/biostatistics/kxj037) is applied for each treatment condition (compound plate-well combination), considering log2-viability values as probes and cell line pool-replicate combinations as batches. (LFC_cb column of Repurposing_Public_24Q2_LFC.csv)
#
#         6. Log2-fold changes are median-collapsed across plates for each cell line perturbation combination (Repurposing_Public_24Q2_LFC_COLLAPSED.csv).
#
#         7. Finally collapsed log2-fold changes are casted into matrix form and concatenated with the previously published PRISM Repurposing Primary dataset for convenience (Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv). For the meta-data of this matrix, please see Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv.

# %% [markdown]
#     # ------------------------------ #
#     # ---- DESCRIPTION OF FILES ---- #
#     # ------------------------------ #
#
#     This data release contains two most recent PRISM Repurposing screens: Repurposing-1M and Repurposing-300. All Repurposing-1M [REP1M] and Repurposing-300 [REP300] compounds (1522 = 1280 REP1M + 242 REP300) were screened in the PRISM assay at a dose of 2.5 μM with a 5-day treatment against 906 cancer cell lines (859 of them passed quality checks -QC- for all tested compound with two high quality replicates). Two PRISM cell line collections were used in the assay: PR500A, which includes only adherent cell lines, and PR500B, which has adherent and suspension cell lines. Together, these PRISM cell line collections form the PR1000 cell line collection. All compounds were run in triplicate, and each plate contained positive (Bortezomib, 20μM) and negative (DMSO) controls. The screen can be considered an extension of the PRISM Repurposing Primary Screen, with PR500A mainly covering the existing cell line panel, while PR500B extends the cell line collection with new subtypes and lineages. For the assay details, please refer to Corsello et al., 2020 (doi.org/10.1038/s43018-019-0018-6) and https://www.theprismlab.org.
#
#     # QC TABLE AND LOWER LEVEL DATA
#     # PROCESSED DATA FILES

# %%
# # read Repurposing_Public_24Q2_Readme.txt
# !cat '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_Readme.txt'

# %%
ls '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/'
# Out:
# README.txt
# Repurposing_Public_24Q2_Cell_Line_Meta_Data.csv
# Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv
# Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv
# Repurposing_Public_24Q2_LFC_COLLAPSED.csv
# Repurposing_Public_24Q2_LFC.csv
# Repurposing_Public_24Q2_LMFI_matrix.csv
# Repurposing_Public_24Q2_LMFI_NORMALIZED.csv
# Repurposing_Public_24Q2_QC_table.csv
# Repurposing_Public_24Q2_Readme.txt
# Repurposing_Public_24Q2_Treatment_Meta_Data.csv
# Repurposing_Public_24Q2.zip

# %% [markdown]
# ### METADATA FILES
# - `Repurposing_Public_24Q2_Cell_Line_Meta_Data.csv`
# - `Repurposing_Public_24Q2_Treatment_Meta_Data.csv`

# %%
# ## Repurposing_Public_24Q2_Cell_Line_Meta_Data.csv 
# Contains the meta data about the  cell lines  screened in the assay, a list of columns with simple descriptions are given below:
# * ccle_name / depmap_id : CCLE and arxspan identifiers for each cell line, please use these to join with other depmap datasets.
# * pool_id: Pool identifier of each cell line, please note that some cell lines are included in more than one pool.
# * culture: The cell set for each cell line. Takes values PR500A or PR500B. Please note, some cell lines are included in both cell sets.
# * row_id: The unique identifier for each row of the raw LMFI values (Repurposing_Public_24Q2_LMFI_matrix.csv), please use this column to join with other data tables in this release.
# * screen: Takes the values of "REP1M" and "REP300" to represent the particular run that the data is generated.  

Cell_Line_Meta_Data = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_Cell_Line_Meta_Data.csv'
)

# %%
# ## Repurposing_Public_24Q2_Treatment_Meta_Data.csv 
# Contains the meta data about the treatment/perturbation in each well of each plate. A list of column names with simple descriptions are given below:
# * profile_id: The unique identifier for each prism_replicate (detection plate), perturbation well, and screen. Please use this column to join with the other data tables. This column also represents the column names of Repurposing_Public_24Q2_LMFI_matrix.csv.
# * culture: The cell set for each prism_replicate. Takes values PR500A or PR500B. 
# * compound_plate: Unique identifier for each compound plate.
# * prism_replicate: Unique identifier for each detection plate (3 for each compound plate x culture pair)
# * rep: Replicate code for each prism_replicate, takes values of X1, X2 and X3.
# * perturbation_type: Takes one of the following 3 values: ctl_vehicle (negative control/DMSO), trt_cp (test compound/treatment), trt_poscon (positive control/Bortezomib) 
# * perturbation_well: Physical location of each perturbation on each detection plate (prism replicate)
# * dose: Dose of the treatment (in uM).
# * broad_id: Unique identifier for each compound. Please note, there might be multiple broad_id's corresponding to each compound but there is only a single compound for each broad_id. 
# * name: Name of the compound treatment, according to the Drug Repurposing Hub (https://clue.io/repurposing)
# * screen: Takes the values of "REP1M" and "REP300" to represent the particular run that the data is generated.

Treatment_Meta_Data = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_Treatment_Meta_Data.csv'
)

# %% [markdown]
# ### QC TABLE AND LOWER LEVEL DATA
#
# - `Repurposing_Public_24Q2_LMFI_matrix.csv`
# - `Repurposing_Public_24Q2_LMFI_NORMALIZED.csv`
# - `Repurposing_Public_24Q2_QC_table.csv`
# - `Repurposing_Public_24Q2_LFC.csv`

# %%
# ## Repurposing_Public_24Q2_LMFI_NORMALIZED.csv 
# Contains the log2 median fluorescence intensity values before and after normalizing them to spike in barcodes. List of column names follows: 
# * row_id: The unique identifier for each row of the raw LMFI values (Repurposing_Public_24Q2_LMFI_matrix.csv), please use this column to join with other data tables in this release.
# * profile_id: The unique identifier for each prism_replicate (detection plate), perturbation well, and screen. Please use this column to join with the other data tables. 
# * LMFI: log2 median fluorescence intensity values for each cell line perturbation pair.
# * LMFI.ref: Reference values for the control barcodes used for normalization. These values are computed as the centered median LMFI values among negative control wells for each spike-in barcode in each detection plate (prism replicate).
# * LMFI.normalized: LMFI values after normalizing them using the control barcodes (spike-in's) to make all wells on the same plate are in the same scale.
# * LMFI.normalized.se: The standard errors for the normalization step, these rough values are not used in the rest of the pipeline but can be examined for more detailed troubleshooting.

LMFI_NORMALIZED = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_LMFI_NORMALIZED.csv'
)

# %%
# ## Repurposing_Public_24Q2_QC_table.csv 
# Contains the QC metrics for each cell line x detection plate pairs. A list of columns and brief explanations are given below.
# * row_id: The unique identifier for each row of the raw LMFI values (Repurposing_Public_24Q2_LMFI_matrix.csv), please use this column to join with other data tables in this release.
# * culture: The cell set for each prism_replicate. Takes values PR500A or PR500B. 
# * compound_plate: Unique identifier for each compound plate.
# * prism_replicate: Unique identifier for each detection plate (3 for each compound plate x culture pair)
# * screen: Takes the values of "REP1M" and "REP300" to represent the particular run that the data is generated.
# * error_rate : Bayes error while classifying negative and positive control wells for each cell line x detection plate pair.
# * NC.median / PC.median : The median normalized LMFI values for negative/positive control wells in a given detection plate (prism_replicate) 
# * NC.mad / PC.mad : The median absolude deviation (MAD) of normalized LMFI values for negative/positive control wells in a given detection plate (prism_replicate) 
# * SSMD : Strictily standardized mean difference, defined as (ctl_vehicle_md-trt_poscon_md)/sqrt(ctl_vehicle_mad^2+trt_poscon_mad^2)
# * DR : Dynamic range of the assay, defined as the median LFC of high dose bortezomib, i.e. ctl_vehicle_md - trt_poscon_md
# * PASS : TRUE iff error_rate < .05 and DR > 2. Flags a QC failure if it is FALSE.
# * n.PASS : How many replicates of the corresponding compound_plate x row_name pair passes the QC. Cell lines with n.PASS < 2 are filtered out for the rest of the analysis.

QC_table = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_QC_table.csv'
)

# %%
# ## Repurposing_Public_24Q2_LFC.csv 
# Contains the log2-fold changes between the perturbations and the median of the negative control wells in each plate. A brief description of the column names is given below.
# * row_id: The unique identifier for each row of the raw LMFI values (Repurposing_Public_24Q2_LMFI_matrix.csv), please use this column to join with other data tables in this release.
# * profile_id: The unique identifier for each prism_replicate (detection plate), perturbation well, and screen. Please use this column to join with the other data tables. 
# * LFC : log2-fold-change values between the normalized LMFI values for each treatment and the median of negative control wells in each detection plate. 
# * LFC_cb : LFC values after applying a batch correction step (ComBat) for potential pooling artifacts. 
# * PASS : Binary flag to decide if this value will be used in the final table/matrix or not. (See Repurposing_Public_24Q2_QC_table.csv)

LFC = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_LFC.csv'
)

# %%
## Repurposing_Public_24Q2_LMFI_matrix.csv : Contains the log2 median fluorescence intensity values for each cell line (or control barcode) and perturbation well. This is the raw data coming from the luminex detection.

LMFI_matrix = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_LMFI_matrix.csv'
)

# %% [markdown]
# ### PROCESSED DATA FILES
# - `Repurposing_Public_24Q2_LFC_COLLAPSED.csv`
# - `Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv`
# - `Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv`

# %%
# ## Repurposing_Public_24Q2_LFC_COLLAPSED.csv
# Log2-fold-change viability values (LFC_cb) computed in Repurposing_Public_24Q2_LFC.csv file are filtered based on the QC results and median collapsed across replicates. The list of the columns in thes data table are described below.
# * row_id: The unique identifier for each row of the raw LMFI values (Repurposing_Public_24Q2_LMFI_matrix.csv), please use this column to join with other data tables in this release.
# * broad_id: Unique identifier for each compound. Please note, there might be multiple broad_id's corresponding to each compound but there is only a single compound for each broad_id. 
# * dose: Dose of the treatment (in uM).
# * compound_plate: Unique identifier for each compound plate.
# * screen: Takes the values of "REP1M" and "REP300" to represent the particular run that the data is generated.
# * culture: The cell set for each prism_replicate. Takes values PR500A or PR500B. 
# * LFC: Median collapsed LFC_cb values from Repurposing_Public_24Q2_LFC.csv (excluding rows with PASS = FALSE).

LFC_COLLAPSED = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_LFC_COLLAPSED.csv'
)

# %%
# ## Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv 
# The final LFC values in Repurposing_Public_24Q2_LFC_collapsed.csv table are cast into a matrix with rows corresponding to individual treatments and columns are depmap_id's. This final matrix also contains the compounds from the original PRISM Repurposing Primary screen for convenience. Please use Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv to get the meta-data for each row.

Extended_Primary_Data_Matrix = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv',
    index_col=0
)

# %%
# ## Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv 
# Metadata for the perturbations represented by each row of Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv. Columns of this table are given below:
# * IDs: Unique identifier to join with the rows of Repurposing_Public_24Q2_Extended_Primary_Data_Matrix.csv
# * screen: Identifier for in which Repurposing screen this particular profile is created.
# * dose: Dose of the treatment (in uM).
# * Drug.Name: Human read-able name for the drug.       
# * repurposing_target: Annotated target of the drug.
# * MOA: Annotated mechanism of action for the drug.
# * Synonyms: Known synonyms of the drug name.

Extended_Primary_Compound_List = pd.read_csv(
    '../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2_Extended_Primary_Compound_List.csv'
)

# %% [markdown]
# ### Create AnnData objects

# %%
Treatment_Meta_Data['name'].unique()
# Out:
# array(['Bortezomib', 'DMSO', nan, ..., 'Fluciclovine', 'AMG-397',
#        'THZ531'], dtype=object)

# %% [markdown]
# ### Create AnnData objects

# %%
import anndata as ad

# %%
# Cell_Line_Meta_Data
# Extended_Primary_Compound_List

# %%
prism_data = ad.AnnData(
    X   = Extended_Primary_Data_Matrix.loc[Extended_Primary_Compound_List['IDs']].T.copy(),
    var = Extended_Primary_Compound_List.set_index('IDs').copy(),
)

prism_data.var.repurposing_target = prism_data.var.repurposing_target.fillna('').astype(str)
prism_data.obs = prism_data.obs.join(can.data.cell_lines)
# add layer name
prism_data.layers['log2FC-viability'] = prism_data.X.copy()
# Out:
# /khayyam/abe/miniconda3/envs/screenpro2/lib/python3.12/site-packages/anndata/_core/anndata.py:1776: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
prism_data.write_h5ad('../CanDI/setup/data/depmap/Repurposing_Public_24Q2/Repurposing_Public_24Q2.h5ad.gz', compression='gzip')
